# %%
# !pip install contractions
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
import seaborn as sns
import unicodedata
import contractions
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score,KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_curve
from sklearn.model_selection import learning_curve
import warnings
import pickle
import opendatasets as od
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Requirement already satisfied: contractions in c:\users\onkar\anaconda3\lib\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\onkar\anaconda3\lib\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\onkar\anaconda3\lib\site-packages (from textsearch>=0.0.21->contractions) (0.3.1)
# Requirement already satisfied: pyahocorasick in c:\users\onkar\anaconda3\lib\site-packages (from textsearch>=0.0.21->contractions) (2.0.0)

# %% [markdown]
# **DATA ACQUISITION**

# %%
od.download('https://www.kaggle.com/datasets/kazanova/sentiment140')
# Out:
# Skipping, found downloaded files in ".\sentiment140" (use force=True to force download)

# %%
col_names = ['target', 'id', 'date', 'flag', 'user', 'text']
non_depressed_1=pd.read_csv('training.1600000.processed.noemoticon.csv',encoding='ISO-8859-1',names=col_names)

# %%
non_depressed_1.head()
# Out:
#    target          id                          date      flag  \
# 0       0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
#https://github.com/ram574/Detecting-Depression-using-Tweets

# %%
final_data= pd.read_csv('OurMLdataset.csv')

# %%
final_data
# Out:
#                 id                                              tweet  label
# 0     1.228030e+18  cmon do not you want to see what kind of tatto...      0
# 1     5.158770e+17  what we need to do in life to be at peace when...      0
# 2     8.377520e+17  finish my research poster to present at a conf...      0
# 3     9.628340e+17                                   i be the problem      1
# 4     4.533340e+17  get to see my idol the other day wish she be s...      1
# ...            ...                                                ...    ...
# 7647  2.923020e+17  if you want to achieve anything in this world ...      0
# 7648  1.386030e+18  i have be wait to get verify before i send thi...      0
# 7649  9.460330e+17  i only lie so i do not have to see tear of dis...      1
# 7650  1.123660e+18  i tell my therapist i just want to be as happy...      0
# 7651  1.219850e+18  when i look at trump lawyer jay sekulow i see ...      0
#
# [7652 rows x 3 columns]

# %% [markdown]
# **PREPROCESSING**

# %%
print("Dimensions of our Dataset: ", final_data.shape)
print("\n")

print("Datset Info: \n")
final_data.info()
# Out:
# Dimensions of our Dataset:  (7652, 3)
#
#
# Datset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7652 entries, 0 to 7651
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      7652 non-null   float64
#  1   tweet   7652 non-null   object
#  2   label   7652 non-null   int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 179.5+ KB

# %%
print("\033[1m" + "Null Values" + "\033[0m\n")
print(final_data.isnull().sum(), "\n")
print("\033[1m" + "______________________________________________________________________________" + "\033[0m\n")
print("\033[1m" + "Duplicate Values" + "\033[0m\n")
display(final_data[final_data.duplicated(keep=False)])
final_data.drop_duplicates(inplace = True)
final_data.reset_index(inplace=True)
final_data.drop(['index'],axis=1,inplace=True)
print("\n\033[1m" + "New DataSet Shape" + "\033[0m\n")
final_data.shape
# Out:
# Null Values
#
# id       0
# tweet    0
# label    0
# dtype: int64
#
# ______________________________________________________________________________
#
# Duplicate Values
#                 id                                              tweet  label
# 351   1.357910e+18                             excerpt from milk feed      1
# 2828  2.618990e+17  just leave a tap with amaze company a culture ...      0
# 2885  1.357910e+18                             excerpt from milk feed      1
# 5941  2.618990e+17  just leave a tap with amaze company a culture ...      0
# New DataSet Shape
# (7650, 3)

# %%
tweet_length = final_data["tweet"].apply(len)
plt.figure(figsize=(10,5))
sns.histplot(tweet_length, color='pink')
plt.title("Distribution of Lengths of all Tweets")
plt.show()

# %%
tweet_length
# Out:
# 0        76
# 1        71
# 2       121
# 3        16
# 4        91
#        ...
# 7645    109
# 7646    160
# 7647     68
# 7648     71
# 7649     94
# Name: tweet, Length: 7650, dtype: int64

# %%
Counts=final_data.label.value_counts()
Counts.rename(index={0: 'Non-Depressive', 1: 'Depressive'}, inplace=True)
print("Number of tweets for each depressive and non depressive category: \n", Counts)
print("\n")
Counts.plot(kind='bar', figsize=(8,8), ylabel='Number of posts', xlabel='Category', title='Bar graph for types of tweets', color='yellow', edgecolor = 'black')
plt.xticks(rotation=360)
plt.show()
# Out:
# Number of tweets for each depressive and non depressive category:
#  Non-Depressive    4592
# Depressive        3058
# Name: label, dtype: int64

# %%
final_data.drop(['id'], axis=1, inplace = True)
data_before_preprocessing = final_data.copy(deep=True)

# %%
data_before_preprocessing = final_data.copy(deep=True)
data_before_preprocessing
# Out:
#                                                   tweet  label
# 0     cmon do not you want to see what kind of tatto...      0
# 1     what we need to do in life to be at peace when...      0
# 2     finish my research poster to present at a conf...      0
# 3                                      i be the problem      1
# 4     get to see my idol the other day wish she be s...      1
# ...                                                 ...    ...
# 7645  if you want to achieve anything in this world ...      0
# 7646  i have be wait to get verify before i send thi...      0
# 7647  i only lie so i do not have to see tear of dis...      1
# 7648  i tell my therapist i just want to be as happy...      0
# 7649  when i look at trump lawyer jay sekulow i see ...      0
#
# [7650 rows x 2 columns]

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\onkar\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: joblib in c:\users\onkar\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in c:\users\onkar\anaconda3\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in c:\users\onkar\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\onkar\anaconda3\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: colorama in c:\users\onkar\anaconda3\lib\site-packages (from click->nltk) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Removing URL links from texts.
for i in range(final_data.shape[0]):
    processed_tweet_1 = re.sub(r"http\S+",' ', final_data._get_value(i, 'tweet'))
    final_data._set_value(i, 'tweet', processed_tweet_1)

# Removing non-ascii-characters.
for i in range(final_data.shape[0]):
    t = final_data._get_value(i, 'tweet')
    t = [w for w in t.split(' ')]
    new_words = []
    for word in t:
        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        new_words.append(new_word)
    t = " ".join(new_words)
    final_data._set_value(i, 'tweet', t)

# Expanding Contractions
for i in range(final_data.shape[0]):
    tweet = final_data._get_value(i, 'tweet')
    expanded_tweet = contractions.fix(tweet)
    final_data._set_value(i, 'tweet', expanded_tweet)

# Converting to lower case
final_data["tweet"] = final_data["tweet"].str.lower()

# Removing @ mentions from the tweets.
for i in range(final_data.shape[0]):
    tweet = final_data._get_value(i, 'tweet')
    clean_tweet = re.sub("@[A-Za-z0-9_]+","", tweet)
    final_data._set_value(i, 'tweet', clean_tweet)

#removing special characters and numbers from texts.
for i in range(final_data.shape[0]):
    t = final_data._get_value(i, 'tweet')
    p = re.compile('\W+')
    t = re.sub(p, ' ', t)
    p = re.compile(r'[0-9]')
    t = re.sub(p, ' ', t)
    p = re.compile(r'[_+]')
    t = re.sub(p, ' ', t)
    final_data._set_value(i, 'tweet',t)

# Removing extra space
for i in range(final_data.shape[0]):
    t = final_data._get_value(i, 'tweet')
    p = re.compile('\s+')
    t = re.sub(p, ' ', t)
    final_data._set_value(i, 'tweet', t)

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

# remove stop words
remove_words = stopwords.words("english")
for i in range(final_data.shape[0]):
    t = final_data._get_value(i, 'tweet')
    t = " ".join([w for w in t.split(' ') if w not in remove_words])
    final_data._set_value(i, 'tweet', t)

#Lemmatization (grouping similar words)
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
nltk.download('wordnet')
for i in range(final_data.shape[0]):
    t = final_data._get_value(i, 'tweet')
    t = " ".join([lemmatizer.lemmatize(w) for w in t.split(' ')])
    final_data._set_value(i, 'tweet', t)

# %%
#for i in range(final_data.shape[0]):
#    tweet = final_data._get_value(i, 'tweet')
#    tweet
#    print(tweet)

# %%
print("Text before preprocessing :", data_before_preprocessing.iloc[89,0], "\n")
print("Text after preprocessing :", final_data.iloc[89,0], "\n")
# Out:
# Text before preprocessing : 8 have sex yes
#
# Text after preprocessing :  sex yes

# %%
def imp_words(relevant_data, data):
    vec = TfidfVectorizer().fit(data)
    bag_of_words = vec.transform(relevant_data)
    words_sum = bag_of_words.sum(axis=0) 
    words_freq = [(word, words_sum[0, idx]) for word, idx in vec.vocabulary_.items()]
    imp_words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
    imp_words_freq = imp_words_freq[:20]
    return imp_words_freq

depressive_data = final_data[final_data['label'] == 1]
imp_depressive_words = imp_words(depressive_data['tweet'], final_data['tweet'])

plt.figure(figsize=(30,9))
plt.subplot(1, 2, 1)
words = [x[0] for x in imp_depressive_words]
imp = [x[1] for x in imp_depressive_words]
sns.barplot(x = imp, y = words)
plt.xlabel('Importance - tfidf value')
plt.title('Important Words in Depressive Tweets')

non_depressive_data = final_data[final_data['label'] == 0]
imp_non_depressive_words = imp_words(non_depressive_data['tweet'], final_data['tweet'])

plt.subplot(1, 2, 2)
words = [x[0] for x in imp_non_depressive_words]
imp = [x[1] for x in imp_non_depressive_words]
sns.barplot(x = imp, y = words)
plt.xlabel('Importance - tfidf value')
plt.title('Important Words in Non-Depressive Tweets')
plt.savefig('bar.png')
plt.show()

# %%
depressive_data= final_data[final_data['label']==1]
tweets = " ".join(depressive_data['tweet'].tolist())
wordcount=WordCloud(background_color="black", max_words=200, contour_width=3, stopwords=remove_words)
wordcount.generate(tweets)
plt.figure(figsize=(30,10))
plt.subplot(1, 2, 1)
plt.axis("off")
plt.title("Depressive Tweet's WordCloud")
plt.imshow(wordcount, interpolation='bilinear')

print()

non_depressive_data= final_data[final_data['label']==0]
tweets = " ".join(non_depressive_data['tweet'].tolist())
wordcount=WordCloud(background_color="white", max_words=200, contour_width=3, stopwords=remove_words)
wordcount.generate(tweets)
plt.subplot(1, 2, 2)
plt.axis("off")
plt.title("Non-Depressive Tweet's WordCloud")
plt.imshow(wordcount, interpolation='bilinear')
plt.savefig('word_cloud.png')
plt.show()

# %% [markdown]
# **Feature Extraction**

# %%
frequency = final_data.tweet.str.split(expand = True).stack().value_counts()
relevant_words = frequency[frequency.values >= 10]
relevant_words
# Out:
# get            605
# want           553
# people         550
# like           540
# go             508
#               ...
# officially      10
# involve         10
# acknowledge     10
# define          10
# shake           10
# Length: 1038, dtype: int64

# %%
tweet_list = final_data.tweet.to_list()
vec = CountVectorizer(stop_words='english', max_features= len(relevant_words))
features = vec.fit_transform(tweet_list)
transformer = TfidfTransformer()
final_features =  transformer.fit_transform(features).toarray()
X = pd.DataFrame(final_features)
y = final_data['label']

# %% [markdown]
# **Train - Test Split**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6885, 1038), (765, 1038), (6885,), (765,))

# %% [markdown]
# **LEARNING TECHNIQUES**

# %% [markdown]
# **Baseline model -** LOGISTIC REGRESSION

# %%
# Logistic regression
a = LogisticRegression(penalty="none", max_iter = 1000, C = 1, solver="lbfgs")
kf = KFold(n_splits=10, random_state = 42, shuffle = True)
score = cross_val_score(a, X_train, y_train, cv=kf, scoring='accuracy')
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))
# Out:
# Cross Validation Scores are [0.82438316 0.83599419 0.81132075 0.82293179 0.81422351 0.8125
#  0.82267442 0.82848837 0.83139535 0.81540698]
# Average Cross Validation score :0.8219318527019274

# %%
C = np.logspace(-3,3,7)
penalty = ["l1","l2"]
solver = ["liblinear"]
max_iter = [100, 500, 1000, 1500]

'''param_grid = dict(C=C, penalty = penalty, solver = solver, max_iter = max_iter)'''

param_grid = dict(C=C, penalty = penalty, solver = solver, max_iter = max_iter)
classifier = LogisticRegression(C=C, penalty = penalty, solver = solver, max_iter = max_iter)
grid = GridSearchCV(estimator=classifier, param_grid=param_grid, cv = 5)
results = grid.fit(X_train, y_train)

# Summarize the results in a readable format
print("Best: {0}, using {1}".format(results.cv_results_['mean_test_score'].max(), results.best_params_))
df_log_reg = pd.DataFrame(results.cv_results_)
df_log_reg
# Out:
# Best: 0.8379084967320262, using {'C': 10.0, 'max_iter': 100, 'penalty': 'l2', 'solver': 'liblinear'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.101652      0.064872         0.015445        0.001545   0.001
# 1        0.060718      0.009473         0.008656        0.000404   0.001
# 2        0.062395      0.013240         0.009359        0.001997   0.001
# 3        0.063918      0.008825         0.013931        0.003895   0.001
# 4        0.072983      0.010684         0.013745        0.004431   0.001
# 5        0.068407      0.010962         0.010625        0.003718   0.001
# 6        0.069729      0.009325         0.011369        0.003464   0.001
# 7        0.065034      0.006154         0.010747        0.003580   0.001
# 8        0.066630      0.011121         0.009778        0.002106    0.01
# 9        0.057739      0.008592         0.013124        0.003946    0.01
# 10       0.061400      0.011696         0.010738        0.003198    0.01
# 11       0.067503      0.013266         0.012773        0.005745    0.01
# 12       0.062774      0.014405         0.009569        0.001183    0.01
# 13       0.083699      0.006139         0.012628        0.003197    0.01
# 14       0.067640      0.012437         0.010363        0.002396    0.01
# 15       0.086546      0.008904         0.012154        0.003893    0.01
# 16       0.075091      0.012605         0.010459        0.001854     0.1
# 17       0.073166      0.010084         0.011384        0.001410     0.1
# 18       0.075377      0.006950         0.013033        0.003456     0.1
# 19       0.067286      0.010659         0.011173        0.002907     0.1
# 20       0.066093      0.012781         0.010291        0.001791     0.1
# 21       0.065816      0.012750         0.011933        0.003715     0.1
# 22       0.064035      0.012983         0.010582        0.003724     0.1
# 23       0.062993      0.011509         0.008743        0.000971     0.1
# 24       0.066596      0.009000         0.008373        0.000528     1.0
# 25       0.070494      0.007207         0.011297        0.003961     1.0
# 26       0.070050      0.011779         0.009572        0.001368     1.0
# 27       0.065625      0.008334         0.010571        0.003279     1.0
# 28       0.071627      0.018188         0.011348        0.003826     1.0
# 29       0.069893      0.009157         0.011179        0.003460     1.0
# 30       0.066791      0.009305         0.009378        0.001343     1.0
# 31       0.059927      0.008378         0.009384        0.001915     1.0
# 32       0.062208      0.013069         0.009334        0.000840    10.0
# 33       0.078132      0.012464         0.009684        0.002217    10.0
# 34       0.070197      0.011766         0.010895        0.003333    10.0
# 35       0.069104      0.002963         0.008994        0.001195    10.0
# 36       0.086348      0.012660         0.009978        0.002028    10.0
# 37       0.068776      0.015666         0.011154        0.003182    10.0
# 38       0.072220      0.017340         0.008778        0.000378    10.0
# 39       0.086717      0.011121         0.010954        0.003013    10.0
# 40       0.078367      0.017057         0.012237        0.004645   100.0
# 41       0.092606      0.004473         0.008451        0.000413   100.0
# 42       0.082671      0.015956         0.011345        0.003022   100.0
# 43       0.081917      0.019009         0.010746        0.003083   100.0
# 44       0.091571      0.003370         0.008738        0.000402   100.0
# 45       0.092364      0.020117         0.009782        0.002092   100.0
# 46       0.086168      0.015978         0.012522        0.003661   100.0
# 47       0.078416      0.016561         0.012780        0.003480   100.0
# 48       0.067919      0.012612         0.009131        0.000776  1000.0
# 49       0.106452      0.015188         0.011764        0.005149  1000.0
# 50       0.065693      0.008723         0.008634        0.001171  1000.0
# 51       0.107650      0.020921         0.009629        0.002389  1000.0
# 52       0.078878      0.014670         0.011758        0.003696  1000.0
# 53       0.097796      0.017920         0.011158        0.003125  1000.0
# 54       0.078277      0.013599         0.012828        0.003251  1000.0
# 55       0.112253      0.024785         0.011549        0.003740  1000.0
#
#    param_max_iter param_penalty param_solver  \
# 0             100            l1    liblinear
# 1             100            l2    liblinear
# 2             500            l1    liblinear
# 3             500            l2    liblinear
# 4            1000            l1    liblinear
# 5            1000            l2    liblinear
# 6            1500            l1    liblinear
# 7            1500            l2    liblinear
# 8             100            l1    liblinear
# 9             100            l2    liblinear
# 10            500            l1    liblinear
# 11            500            l2    liblinear
# 12           1000            l1    liblinear
# 13           1000            l2    liblinear
# 14           1500            l1    liblinear
# 15           1500            l2    liblinear
# 16            100            l1    liblinear
# 17            100            l2    liblinear
# 18            500            l1    liblinear
# 19            500            l2    liblinear
# 20           1000            l1    liblinear
# 21           1000            l2    liblinear
# 22           1500            l1    liblinear
# 23           1500            l2    liblinear
# 24            100            l1    liblinear
# 25            100            l2    liblinear
# 26            500            l1    liblinear
# 27            500            l2    liblinear
# 28           1000            l1    liblinear
# 29           1000            l2    liblinear
# 30           1500            l1    liblinear
# 31           1500            l2    liblinear
# 32            100            l1    liblinear
# 33            100            l2    liblinear
# 34            500            l1    liblinear
# 35            500            l2    liblinear
# 36           1000            l1    liblinear
# 37           1000            l2    liblinear
# 38           1500            l1    liblinear
# 39           1500            l2    liblinear
# 40            100            l1    liblinear
# 41            100            l2    liblinear
# 42            500            l1    liblinear
# 43            500            l2    liblinear
# 44           1000            l1    liblinear
# 45           1000            l2    liblinear
# 46           1500            l1    liblinear
# 47           1500            l2    liblinear
# 48            100            l1    liblinear
# 49            100            l2    liblinear
# 50            500            l1    liblinear
# 51            500            l2    liblinear
# 52           1000            l1    liblinear
# 53           1000            l2    liblinear
# 54           1500            l1    liblinear
# 55           1500            l2    liblinear
#
#                                                params  split0_test_score  \
# 0   {'C': 0.001, 'max_iter': 100, 'penalty': 'l1',...           0.599855
# 1   {'C': 0.001, 'max_iter': 100, 'penalty': 'l2',...           0.599855
# 2   {'C': 0.001, 'max_iter': 500, 'penalty': 'l1',...           0.599855
# 3   {'C': 0.001, 'max_iter': 500, 'penalty': 'l2',...           0.599855
# 4   {'C': 0.001, 'max_iter': 1000, 'penalty': 'l1'...           0.599855
# 5   {'C': 0.001, 'max_iter': 1000, 'penalty': 'l2'...           0.599855
# 6   {'C': 0.001, 'max_iter': 1500, 'penalty': 'l1'...           0.599855
# 7   {'C': 0.001, 'max_iter': 1500, 'penalty': 'l2'...           0.599855
# 8   {'C': 0.01, 'max_iter': 100, 'penalty': 'l1', ...           0.599855
# 9   {'C': 0.01, 'max_iter': 100, 'penalty': 'l2', ...           0.599855
# 10  {'C': 0.01, 'max_iter': 500, 'penalty': 'l1', ...           0.599855
# 11  {'C': 0.01, 'max_iter': 500, 'penalty': 'l2', ...           0.599855
# 12  {'C': 0.01, 'max_iter': 1000, 'penalty': 'l1',...           0.599855
# 13  {'C': 0.01, 'max_iter': 1000, 'penalty': 'l2',...           0.599855
# 14  {'C': 0.01, 'max_iter': 1500, 'penalty': 'l1',...           0.599855
# 15  {'C': 0.01, 'max_iter': 1500, 'penalty': 'l2',...           0.599855
# 16  {'C': 0.1, 'max_iter': 100, 'penalty': 'l1', '...           0.664488
# 17  {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', '...           0.742193
# 18  {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...           0.664488
# 19  {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...           0.742193
# 20  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l1', ...           0.664488
# 21  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', ...           0.742193
# 22  {'C': 0.1, 'max_iter': 1500, 'penalty': 'l1', ...           0.664488
# 23  {'C': 0.1, 'max_iter': 1500, 'penalty': 'l2', ...           0.742193
# 24  {'C': 1.0, 'max_iter': 100, 'penalty': 'l1', '...           0.813362
# 25  {'C': 1.0, 'max_iter': 100, 'penalty': 'l2', '...           0.828613
# 26  {'C': 1.0, 'max_iter': 500, 'penalty': 'l1', '...           0.813362
# 27  {'C': 1.0, 'max_iter': 500, 'penalty': 'l2', '...           0.828613
# 28  {'C': 1.0, 'max_iter': 1000, 'penalty': 'l1', ...           0.813362
# 29  {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2', ...           0.828613
# 30  {'C': 1.0, 'max_iter': 1500, 'penalty': 'l1', ...           0.813362
# 31  {'C': 1.0, 'max_iter': 1500, 'penalty': 'l2', ...           0.828613
# 32  {'C': 10.0, 'max_iter': 100, 'penalty': 'l1', ...           0.829339
# 33  {'C': 10.0, 'max_iter': 100, 'penalty': 'l2', ...           0.840959
# 34  {'C': 10.0, 'max_iter': 500, 'penalty': 'l1', ...           0.829339
# 35  {'C': 10.0, 'max_iter': 500, 'penalty': 'l2', ...           0.840959
# 36  {'C': 10.0, 'max_iter': 1000, 'penalty': 'l1',...           0.829339
# 37  {'C': 10.0, 'max_iter': 1000, 'penalty': 'l2',...           0.840959
# 38  {'C': 10.0, 'max_iter': 1500, 'penalty': 'l1',...           0.829339
# 39  {'C': 10.0, 'max_iter': 1500, 'penalty': 'l2',...           0.840959
# 40  {'C': 100.0, 'max_iter': 100, 'penalty': 'l1',...           0.814089
# 41  {'C': 100.0, 'max_iter': 100, 'penalty': 'l2',...           0.824256
# 42  {'C': 100.0, 'max_iter': 500, 'penalty': 'l1',...           0.814089
# 43  {'C': 100.0, 'max_iter': 500, 'penalty': 'l2',...           0.824256
# 44  {'C': 100.0, 'max_iter': 1000, 'penalty': 'l1'...           0.814089
# 45  {'C': 100.0, 'max_iter': 1000, 'penalty': 'l2'...           0.824256
# 46  {'C': 100.0, 'max_iter': 1500, 'penalty': 'l1'...           0.814089
# 47  {'C': 100.0, 'max_iter': 1500, 'penalty': 'l2'...           0.824256
# 48  {'C': 1000.0, 'max_iter': 100, 'penalty': 'l1'...           0.809731
# 49  {'C': 1000.0, 'max_iter': 100, 'penalty': 'l2'...           0.814815
# 50  {'C': 1000.0, 'max_iter': 500, 'penalty': 'l1'...           0.810458
# 51  {'C': 1000.0, 'max_iter': 500, 'penalty': 'l2'...           0.814815
# 52  {'C': 1000.0, 'max_iter': 1000, 'penalty': 'l1...           0.811184
# 53  {'C': 1000.0, 'max_iter': 1000, 'penalty': 'l2...           0.814815
# 54  {'C': 1000.0, 'max_iter': 1500, 'penalty': 'l1...           0.809731
# 55  {'C': 1000.0, 'max_iter': 1500, 'penalty': 'l2...           0.814815
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.599855           0.600581           0.600581
# 1            0.599855           0.600581           0.600581
# 2            0.599855           0.600581           0.600581
# 3            0.599855           0.600581           0.600581
# 4            0.599855           0.600581           0.600581
# 5            0.599855           0.600581           0.600581
# 6            0.599855           0.600581           0.600581
# 7            0.599855           0.600581           0.600581
# 8            0.599855           0.600581           0.600581
# 9            0.600581           0.601307           0.601307
# 10           0.599855           0.600581           0.600581
# 11           0.600581           0.601307           0.601307
# 12           0.599855           0.600581           0.600581
# 13           0.600581           0.601307           0.601307
# 14           0.599855           0.600581           0.600581
# 15           0.600581           0.601307           0.601307
# 16           0.684822           0.681191           0.679739
# 17           0.751634           0.748729           0.753813
# 18           0.684822           0.681191           0.679739
# 19           0.751634           0.748729           0.753813
# 20           0.684822           0.681191           0.679739
# 21           0.751634           0.748729           0.753813
# 22           0.684822           0.681191           0.679739
# 23           0.751634           0.748729           0.753813
# 24           0.804648           0.814089           0.798838
# 25           0.822803           0.831518           0.818446
# 26           0.804648           0.814089           0.798838
# 27           0.822803           0.831518           0.818446
# 28           0.804648           0.814089           0.798838
# 29           0.822803           0.831518           0.818446
# 30           0.804648           0.814089           0.798838
# 31           0.822803           0.831518           0.818446
# 32           0.833696           0.844590           0.806826
# 33           0.840959           0.856209           0.817720
# 34           0.833696           0.844590           0.806826
# 35           0.840959           0.856209           0.817720
# 36           0.833696           0.844590           0.806826
# 37           0.840959           0.856209           0.817720
# 38           0.833696           0.844590           0.806826
# 39           0.840959           0.856209           0.817720
# 40           0.819898           0.834423           0.799564
# 41           0.826434           0.846042           0.804648
# 42           0.819898           0.832970           0.799564
# 43           0.826434           0.846042           0.804648
# 44           0.819898           0.832970           0.799564
# 45           0.826434           0.846042           0.804648
# 46           0.819898           0.832970           0.799564
# 47           0.826434           0.846042           0.804648
# 48           0.816993           0.831518           0.795207
# 49           0.816267           0.837328           0.798112
# 50           0.816267           0.831518           0.795207
# 51           0.816267           0.837328           0.798112
# 52           0.816267           0.831518           0.795207
# 53           0.816267           0.837328           0.798112
# 54           0.816993           0.831518           0.795207
# 55           0.816267           0.837328           0.798112
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.600581         0.600290        0.000356               45
# 1            0.600581         0.600290        0.000356               45
# 2            0.600581         0.600290        0.000356               45
# 3            0.600581         0.600290        0.000356               45
# 4            0.600581         0.600290        0.000356               45
# 5            0.600581         0.600290        0.000356               45
# 6            0.600581         0.600290        0.000356               45
# 7            0.600581         0.600290        0.000356               45
# 8            0.600581         0.600290        0.000356               45
# 9            0.600581         0.600726        0.000543               41
# 10           0.600581         0.600290        0.000356               45
# 11           0.600581         0.600726        0.000543               41
# 12           0.600581         0.600290        0.000356               45
# 13           0.600581         0.600726        0.000543               41
# 14           0.600581         0.600290        0.000356               45
# 15           0.600581         0.600726        0.000543               41
# 16           0.666667         0.675381        0.008203               37
# 17           0.747277         0.748729        0.003978               33
# 18           0.666667         0.675381        0.008203               37
# 19           0.747277         0.748729        0.003978               33
# 20           0.666667         0.675381        0.008203               37
# 21           0.747277         0.748729        0.003978               33
# 22           0.666667         0.675381        0.008203               37
# 23           0.747277         0.748729        0.003978               33
# 24           0.810458         0.808279        0.005773               29
# 25           0.830792         0.826434        0.005031                9
# 26           0.810458         0.808279        0.005773               29
# 27           0.830792         0.826434        0.005031                9
# 28           0.810458         0.808279        0.005773               29
# 29           0.830792         0.826434        0.005031                9
# 30           0.810458         0.808279        0.005773               29
# 31           0.830792         0.826434        0.005031                9
# 32           0.819172         0.826725        0.012865                5
# 33           0.833696         0.837908        0.012481                1
# 34           0.819172         0.826725        0.012865                5
# 35           0.833696         0.837908        0.012481                1
# 36           0.819172         0.826725        0.012865                5
# 37           0.833696         0.837908        0.012481                1
# 38           0.819172         0.826725        0.012865                5
# 39           0.833696         0.837908        0.012481                1
# 40           0.810458         0.815686        0.011477               21
# 41           0.820625         0.824401        0.013243               13
# 42           0.810458         0.815396        0.011008               23
# 43           0.820625         0.824401        0.013243               13
# 44           0.811910         0.815686        0.010892               21
# 45           0.820625         0.824401        0.013243               13
# 46           0.810458         0.815396        0.011008               23
# 47           0.820625         0.824401        0.013243               13
# 48           0.807553         0.812200        0.011938               27
# 49           0.815541         0.816412        0.012455               17
# 50           0.808279         0.812346        0.011805               25
# 51           0.815541         0.816412        0.012455               17
# 52           0.807553         0.812346        0.011841               25
# 53           0.815541         0.816412        0.012455               17
# 54           0.807553         0.812200        0.011938               27
# 55           0.815541         0.816412        0.012455               17

# %%
model = LogisticRegression(C = 10.0, max_iter = 100, penalty = 'l2', solver = 'liblinear')
kf = KFold(n_splits=10, random_state = 42, shuffle = True)
score = cross_val_score(model, X_train, y_train, cv=kf, scoring='accuracy')
print("Cross Validation Scores are {}".format(score))
print("Average Cross Validation score :{}".format(score.mean()))

# Classification Report
print("\n\033[1m"+"Performance on Test Set" + "\033[0m\n")
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))

# Confusion Matrix
print("\n")
plot_confusion_matrix(model, X_test, y_test)  
plt.title("Confusion matrix for Depressive (1)/ Non-Depressive (0) Tweets", size = 10);
plt.savefig('lg_confusion_m.png')
plt.show()

# AUC-ROC Curve
print("\n")
fpr = {}
tpr = {}
thresh = {}
labels = model.classes_
pred_y_prob = model.predict_proba(X_test)
for i in range(2):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, pred_y_prob[:,i],pos_label=labels[i])
      
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label= labels[0])
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label= labels[1])

plt.title("AUC-ROC curve for Logistic Regression")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.show()
# Out:
# Cross Validation Scores are [0.8287373  0.85341074 0.83164006 0.83018868 0.84179971 0.8372093
#  0.85319767 0.8619186  0.83430233 0.84156977]
# Average Cross Validation score :0.8413974162081885
#
# Performance on Test Set
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       459
#            1       0.82      0.80      0.81       306
#
#     accuracy                           0.85       765
#    macro avg       0.85      0.84      0.84       765
# weighted avg       0.85      0.85      0.85       765

# %%
# Learning Curve
train_score = model.score(X_train, y_train)
train_size, train_scores, test_scores = learning_curve(estimator=model, X=X_train, y=y_train, cv=kf, scoring="accuracy", random_state=42)
test_scores = 1-np.mean(test_scores,axis=1)
train_scores = 1-np.mean(train_scores,axis=1)
lc = pd.DataFrame({"Training_size":train_size,"Training_loss":train_scores,"Validation_loss":test_scores}).melt(id_vars="Training_size")
sns.lineplot(x="Training_size", y="value", data=lc, hue="variable")
plt.title("Learning Curve")
plt.ylabel("Misclassification Rate/Loss")
plt.savefig('learning_curve.png')
plt.show()

# %%
pickle.dump(model, open("model_Logistic_reg.pkl", 'wb'))

# %%
data_before_preprocessing.rename(columns={'tweet': 'tweet before preprocessing'}, inplace = True)
error = pd.DataFrame({'Actual_Values': y_test, 'Predicted_Values': predictions})
frames = [data_before_preprocessing.loc[X_test.index, 'tweet before preprocessing'], final_data.loc[X_test.index, 'tweet'], error]
error = pd.concat(frames, axis = 1)
error_analyse = error[error["Actual_Values"]!=error["Predicted_Values"]]
error_analyse
# Out:
#                              tweet before preprocessing  \
# 2337                                 shut the world off
# 3038                            i maintain my innocence
# 4239        have the hard conversations but with myself
# 5160  if there be people who care then there be hope...
# 1430                    you look happy well look closer
# ...                                                 ...
# 1168  it be the first time in a long time that puppe...
# 6591  oh nooooo nobody bet me to post a picture of m...
# 2168          i cannot wait to tell you about my suffer
# 1758  one of those days where i just want to avoid e...
# 31    it be a pleasure get to know you ali i be sorr...
#
#                                                   tweet  Actual_Values  \
# 2337                                         shut world              1
# 3038                                 maintain innocence              0
# 4239                                  hard conversation              1
# 5160                people care hope hope lose one care              0
# 1430                        look happy well look closer              1
# ...                                                 ...            ...
# 1168  first time long time pupper sleep past noon st...              0
# 6591  oh nooooo nobody bet post picture as boyfriend...              0
# 2168                            cannot wait tell suffer              1
# 1758               one day want avoid everyone anything              1
# 31    pleasure get know ali sorry see thigh gym one ...              0
#
#       Predicted_Values
# 2337                 0
# 3038                 1
# 4239                 0
# 5160                 1
# 1430                 0
# ...                ...
# 1168                 1
# 6591                 1
# 2168                 0
# 1758                 0
# 31                   1
#
# [114 rows x 4 columns]

# %%
correct = error[error["Actual_Values"]==error["Predicted_Values"]]
correct
# Out:
#                              tweet before preprocessing  \
# 5752  i be not perfect i make mistake i hurt people ...
# 2465  this might be my best video ever and none of y...
# 5686  judge a leader by their level of service not t...
# 4747  dear mom i be sorry i could not make you any p...
# 5787  hear abbi jacobson find out she pay a nonrefun...
# ...                                                 ...
# 179   if i be go down i be take one with me thank fo...
# 5634  i be pretty sure my iphone be spy on me becaus...
# 5035  i think he be just as do with my study as i be...
# 4500  accord to my new friend food should be waste f...
# 1199                            by relax i mean anxious
#
#                                                   tweet  Actual_Values  \
# 5752  perfect make mistake hurt people say sorry act...              1
# 2465  might best video ever none watch view one bles...              0
# 5686  judge leader level service level privilege u a...              0
# 4747  dear mom sorry could make prouder sorry turn w...              1
# 5787  hear abbi jacobson find pay nonrefundable fee ...              0
# ...                                                 ...            ...
# 179   go take one thank watch fee hang series see gu...              0
# 5634  pretty sure iphone spy start get lot ad water ...              0
# 5035                                    think study zzz              0
# 4500  accord new friend food waste comedic purpose d...              0
# 1199                                 relax mean anxious              1
#
#       Predicted_Values
# 5752                 1
# 2465                 0
# 5686                 0
# 4747                 1
# 5787                 0
# ...                ...
# 179                  0
# 5634                 0
# 5035                 0
# 4500                 0
# 1199                 1
#
# [651 rows x 4 columns]

# %% [markdown]
# **Advanced model -** RNN

# %%
# !pip install keras-tuner
from tensorflow import keras
import keras_tuner as kt
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from keras.layers import Dropout
import tensorflow as tf

# %%
X_test = final_data.loc[X_test.index, 'tweet'].to_frame()
y_test = final_data.loc[y_test.index, 'label']
X_mix = final_data.loc[X_train.index, 'tweet'].to_frame()
y_mix = final_data.loc[y_train.index, 'label']
X_train, X_val, y_train, y_val = train_test_split(X_mix, y_mix, test_size = 0.1, random_state = 42)
X_train.shape, X_test.shape, X_val.shape, y_train.shape, y_test.shape, y_val.shape
# Out:
# ((6196, 1), (765, 1), (689, 1), (6196,), (765,), (689,))

# %%
import tensorflow as tf

# %%
training_data = X_train
training_data["label"] = y_train

testing_data = X_test
testing_data["label"] = y_test

val_data = X_val
val_data["label"] = y_val

training_dataset = (tf.data.Dataset.from_tensor_slices((tf.cast(training_data['tweet'].values, tf.string),tf.cast(training_data['label'].values, tf.int32))))
testing_data = (tf.data.Dataset.from_tensor_slices((tf.cast(testing_data['tweet'].values, tf.string),tf.cast(testing_data['label'].values, tf.int32))))
val_data = (tf.data.Dataset.from_tensor_slices((tf.cast(val_data['tweet'].values, tf.string),tf.cast(val_data['label'].values, tf.int32))))

training_dataset = training_dataset.batch(32).prefetch(tf.data.AUTOTUNE)
testing_data = testing_data.batch(32).prefetch(tf.data.AUTOTUNE)
val_data = val_data.batch(32).prefetch(tf.data.AUTOTUNE)

VOCAB_SIZE = 1000
encoder = tf.keras.layers.TextVectorization(max_tokens=VOCAB_SIZE)
encoder.adapt(training_dataset.map(lambda tweet, label: tweet))

# %%
def model_builder(hp):
    hp_units = hp.Int('units', min_value=16, max_value=512, step=32)
    model = tf.keras.Sequential([encoder,
        tf.keras.layers.Embedding(len(encoder.get_vocabulary()), 32, mask_zero=True),
        tf.keras.layers.SimpleRNN(32),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(units=hp_units, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')
        ])
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                    optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
                    metrics=['accuracy'])
    return model

tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=20,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt_hppp')

es = EarlyStopping(monitor='val_loss', patience=3, verbose=1)
tuner.search(training_dataset, epochs=50, validation_data=val_data, validation_steps=20, callbacks = [es])

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# INFO:tensorflow:Reloading Tuner from my_dir\intro_to_kt_hppp\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 240 and the optimal learning rate for the optimizer
# is 0.001.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(training_dataset, epochs=20, validation_data=val_data, validation_steps=20)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/20
# 194/194 [==============================] - 5s 11ms/step - loss: 0.4607 - accuracy: 0.7658 - val_loss: 0.3464 - val_accuracy: 0.8687
# Epoch 2/20
# 194/194 [==============================] - 2s 9ms/step - loss: 0.2938 - accuracy: 0.8815 - val_loss: 0.3588 - val_accuracy: 0.8625
# Epoch 3/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.2475 - accuracy: 0.8996 - val_loss: 0.3810 - val_accuracy: 0.8609
# Epoch 4/20
# 194/194 [==============================] - 2s 9ms/step - loss: 0.2119 - accuracy: 0.9141 - val_loss: 0.4178 - val_accuracy: 0.8641
# Epoch 5/20
# 194/194 [==============================] - 2s 9ms/step - loss: 0.1713 - accuracy: 0.9335 - val_loss: 0.4697 - val_accuracy: 0.8609
# Epoch 6/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.1420 - accuracy: 0.9438 - val_loss: 0.4940 - val_accuracy: 0.8531
# Epoch 7/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.1193 - accuracy: 0.9564 - val_loss: 0.5700 - val_accuracy: 0.8531
# Epoch 8/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.1118 - accuracy: 0.9588 - val_loss: 0.6257 - val_accuracy: 0.8594
# Epoch 9/20
# 194/194 [==============================] - 2s 11ms/step - loss: 0.0807 - accuracy: 0.9669 - val_loss: 0.6986 - val_accuracy: 0.8609
# Epoch 10/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0687 - accuracy: 0.9734 - val_loss: 0.7386 - val_accuracy: 0.8547
# Epoch 11/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0714 - accuracy: 0.9727 - val_loss: 0.7269 - val_accuracy: 0.8609
# Epoch 12/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0628 - accuracy: 0.9769 - val_loss: 0.8648 - val_accuracy: 0.8516
# Epoch 13/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0649 - accuracy: 0.9748 - val_loss: 0.7471 - val_accuracy: 0.8438
# Epoch 14/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0609 - accuracy: 0.9772 - val_loss: 0.8188 - val_accuracy: 0.8313
# Epoch 15/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0579 - accuracy: 0.9779 - val_loss: 0.8757 - val_accuracy: 0.8328
# Epoch 16/20
# 194/194 [==============================] - 2s 9ms/step - loss: 0.0510 - accuracy: 0.9798 - val_loss: 0.9525 - val_accuracy: 0.8391
# Epoch 17/20
# 194/194 [==============================] - 2s 9ms/step - loss: 0.0551 - accuracy: 0.9790 - val_loss: 0.8753 - val_accuracy: 0.8359
# Epoch 18/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0501 - accuracy: 0.9800 - val_loss: 0.9774 - val_accuracy: 0.8266
# Epoch 19/20
# 194/194 [==============================] - 2s 10ms/step - loss: 0.0423 - accuracy: 0.9813 - val_loss: 0.9969 - val_accuracy: 0.8266
# Epoch 20/20
# 194/194 [==============================] - 2s 9ms/step - loss: 0.0487 - accuracy: 0.9808 - val_loss: 0.9232 - val_accuracy: 0.8109
# Best epoch: 1

# %%
def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend(['Training_'+metric, 'Val_'+metric])
  plt.savefig('rnn_loss_curve.png')

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')

# %%
hypermodel = tuner.hypermodel.build(best_hps)
hypermodel.fit(training_dataset, epochs=best_epoch , validation_data=val_data, validation_steps=20)
# Out:
# 194/194 [==============================] - 5s 13ms/step - loss: 0.4519 - accuracy: 0.7752 - val_loss: 0.3454 - val_accuracy: 0.8578

# %%
pickle.dump(hypermodel, open("model_RNN.pkl", 'wb'))

# %%
eval_result = hypermodel.evaluate(training_dataset)
print("[train loss, train accuracy]:", eval_result)
# Out:
# 194/194 [==============================] - 1s 3ms/step - loss: 0.2738 - accuracy: 0.8915
# [train loss, train accuracy]: [0.2737986147403717, 0.891542911529541]

# %%
eval_result = hypermodel.evaluate(testing_data)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3101 - accuracy: 0.8680
# [test loss, test accuracy]: [0.3101009726524353, 0.8679738640785217]

# %%
predictions = (hypermodel.predict(X_test['tweet']) > 0.5).astype("int32")

# Classification Report
print("\n\033[1m"+"Performance on Test Set" + "\033[0m\n")
print(classification_report(y_test, predictions))

# Confusion Matrix
print("\n")
cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion matrix for Depressive (1)/ Non-Depressive (0) Tweets", size = 10);
plt.savefig('rnn_confusion_m.png')
plt.show()

# AUC-ROC Curve
print("\n")
pred_y_prob = hypermodel.predict(X_test['tweet']).ravel()   
fpr_rnn, tpr_rnn, thresh_rnn = roc_curve(y_test, pred_y_prob)
plt.plot(fpr_rnn, tpr_rnn, linestyle='--',color='orange', label="RNN")
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label="Logistic Regression")

plt.title("AUC-ROC curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('AUC_ROC.png')
plt.show()
# Out:
# 24/24 [==============================] - 0s 4ms/step
#
# Performance on Test Set
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       459
#            1       0.83      0.84      0.84       306
#
#     accuracy                           0.87       765
#    macro avg       0.86      0.86      0.86       765
# weighted avg       0.87      0.87      0.87       765
# 24/24 [==============================] - 0s 4ms/step

# %% [markdown]
# **Advanced model -** LSTM

# %%
def build_model2(hp):
    hp_units = hp.Int('units',min_value=32,max_value=512,step=32)
    hp_drop_rate = hp.Float('rate', min_value=0, max_value=0.9, step=0.1)
    hp_choice = hp.Choice('activation',values=['relu', 'sigmoid'])

    model = tf.keras.Sequential([encoder,
    tf.keras.layers.Embedding(len(encoder.get_vocabulary()), 32, mask_zero=True),
    tf.keras.layers.SpatialDropout1D(rate = hp_drop_rate),
     tf.keras.layers.LSTM(32),
    tf.keras.layers.Dropout(rate = hp_drop_rate),
    tf.keras.layers.Dense(units=hp_units, activation='relu'),
    tf.keras.layers.Dropout(rate = hp_drop_rate),
    tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
              metrics=['accuracy'])
    return model

tuner = kt.Hyperband(build_model2,
                     objective='val_accuracy',
                     max_epochs=20,
                     factor=3,
                     directory='my_dir2',
                     project_name='intro_to_kt2')

es = EarlyStopping(monitor='val_loss', patience=3, verbose=1)
tuner.search(training_dataset, epochs=50, validation_data=val_data, validation_steps=20, callbacks = [es])

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# INFO:tensorflow:Reloading Tuner from my_dir2\intro_to_kt2\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 224 and the optimal learning rate for the optimizer
# is 0.001.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(training_dataset, epochs=20, validation_data=val_data, validation_steps=20)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/20
# 194/194 [==============================] - 11s 23ms/step - loss: 0.5595 - accuracy: 0.6864 - val_loss: 0.4171 - val_accuracy: 0.8172
# Epoch 2/20
# 194/194 [==============================] - 3s 13ms/step - loss: 0.3708 - accuracy: 0.8476 - val_loss: 0.3555 - val_accuracy: 0.8578
# Epoch 3/20
# 194/194 [==============================] - 3s 13ms/step - loss: 0.3259 - accuracy: 0.8693 - val_loss: 0.3489 - val_accuracy: 0.8625
# Epoch 4/20
# 194/194 [==============================] - 3s 13ms/step - loss: 0.2935 - accuracy: 0.8807 - val_loss: 0.3410 - val_accuracy: 0.8656
# Epoch 5/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2746 - accuracy: 0.8888 - val_loss: 0.3543 - val_accuracy: 0.8703
# Epoch 6/20
# 194/194 [==============================] - 3s 17ms/step - loss: 0.2746 - accuracy: 0.8880 - val_loss: 0.3538 - val_accuracy: 0.8672
# Epoch 7/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2650 - accuracy: 0.8915 - val_loss: 0.3476 - val_accuracy: 0.8656
# Epoch 8/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2545 - accuracy: 0.8993 - val_loss: 0.3727 - val_accuracy: 0.8625
# Epoch 9/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2508 - accuracy: 0.8990 - val_loss: 0.3829 - val_accuracy: 0.8625
# Epoch 10/20
# 194/194 [==============================] - 3s 17ms/step - loss: 0.2498 - accuracy: 0.8996 - val_loss: 0.3681 - val_accuracy: 0.8609
# Epoch 11/20
# 194/194 [==============================] - 3s 17ms/step - loss: 0.2428 - accuracy: 0.9019 - val_loss: 0.3658 - val_accuracy: 0.8594
# Epoch 12/20
# 194/194 [==============================] - 3s 15ms/step - loss: 0.2410 - accuracy: 0.9022 - val_loss: 0.3926 - val_accuracy: 0.8641
# Epoch 13/20
# 194/194 [==============================] - 3s 15ms/step - loss: 0.2403 - accuracy: 0.8988 - val_loss: 0.3804 - val_accuracy: 0.8625
# Epoch 14/20
# 194/194 [==============================] - 3s 16ms/step - loss: 0.2335 - accuracy: 0.9056 - val_loss: 0.3808 - val_accuracy: 0.8609
# Epoch 15/20
# 194/194 [==============================] - 3s 15ms/step - loss: 0.2343 - accuracy: 0.9028 - val_loss: 0.3803 - val_accuracy: 0.8625
# Epoch 16/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2298 - accuracy: 0.9075 - val_loss: 0.3989 - val_accuracy: 0.8562
# Epoch 17/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2273 - accuracy: 0.9057 - val_loss: 0.3952 - val_accuracy: 0.8547
# Epoch 18/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2198 - accuracy: 0.9107 - val_loss: 0.4076 - val_accuracy: 0.8578
# Epoch 19/20
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2218 - accuracy: 0.9078 - val_loss: 0.4188 - val_accuracy: 0.8547
# Epoch 20/20
# 194/194 [==============================] - 3s 15ms/step - loss: 0.2215 - accuracy: 0.9114 - val_loss: 0.4199 - val_accuracy: 0.8547
# Best epoch: 5

# %%
def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend(['Training_'+metric, 'Val_'+metric])
  plt.savefig('lstm_loss_curve.png')

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')

# %%
hypermodel = tuner.hypermodel.build(best_hps)
hypermodel.fit(training_dataset, epochs=best_epoch , validation_data=val_data, validation_steps=20)
# Out:
# Epoch 1/5
# 194/194 [==============================] - 13s 25ms/step - loss: 0.5548 - accuracy: 0.7042 - val_loss: 0.4162 - val_accuracy: 0.8266
# Epoch 2/5
# 194/194 [==============================] - 3s 15ms/step - loss: 0.3628 - accuracy: 0.8478 - val_loss: 0.3465 - val_accuracy: 0.8516
# Epoch 3/5
# 194/194 [==============================] - 3s 14ms/step - loss: 0.3168 - accuracy: 0.8725 - val_loss: 0.3509 - val_accuracy: 0.8641
# Epoch 4/5
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2982 - accuracy: 0.8756 - val_loss: 0.3411 - val_accuracy: 0.8672
# Epoch 5/5
# 194/194 [==============================] - 3s 14ms/step - loss: 0.2824 - accuracy: 0.8838 - val_loss: 0.3510 - val_accuracy: 0.8719

# %%
pickle.dump(hypermodel, open("model_LSTM.pkl", 'wb'))

# %%
eval_result = hypermodel.evaluate(training_dataset)
print("[train loss, train accuracy]:", eval_result)
# Out:
# 194/194 [==============================] - 1s 4ms/step - loss: 0.2212 - accuracy: 0.9085
# [train loss, train accuracy]: [0.22121362388134003, 0.9084893465042114]

# %%
eval_result = hypermodel.evaluate(testing_data)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2949 - accuracy: 0.8824
# [test loss, test accuracy]: [0.29490724205970764, 0.8823529481887817]

# %%
eval_result = hypermodel.evaluate(val_data)
print("[validation loss, validation accuracy]:", eval_result)
# Out:
# 22/22 [==============================] - 0s 5ms/step - loss: 0.3453 - accuracy: 0.8723
# [validation loss, validation accuracy]: [0.345310777425766, 0.8722786903381348]

# %%
predictions = (hypermodel.predict(X_test['tweet']) > 0.5).astype("int32")

# Classification Report
print("\n\033[1m"+"Performance on Test Set" + "\033[0m\n")
print(classification_report(y_test, predictions))

# Confusion Matrix
print("\n")
cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion matrix for Depressive (1)/ Non-Depressive (0) Tweets", size = 10);
plt.savefig('rnn_confusion_m.png')
plt.show()

# AUC-ROC Curve
print("\n")
pred_y_prob = hypermodel.predict(X_test['tweet']).ravel()   
fpr_lstm, tpr_lstm, thresh_lstm = roc_curve(y_test, pred_y_prob)
plt.plot(fpr_lstm, tpr_lstm, linestyle='--',color='orange', label="LSTM")
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label="Logistic Regression")

plt.title("AUC-ROC curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('AUC_ROC.png')
plt.show()
# Out:
# 24/24 [==============================] - 2s 6ms/step
#
# Performance on Test Set
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90       459
#            1       0.88      0.82      0.85       306
#
#     accuracy                           0.88       765
#    macro avg       0.88      0.87      0.88       765
# weighted avg       0.88      0.88      0.88       765
# 24/24 [==============================] - 0s 5ms/step

# %% [markdown]
# **Advanced model -** CNN

# %%
def model_builder(hp):
    hp_units = hp.Int('units', min_value=16, max_value=512, step=32)
    model = tf.keras.Sequential([encoder,
    tf.keras.layers.Embedding(len(encoder.get_vocabulary()), 32, mask_zero=True),
    tf.keras.layers.Conv1D(filters=32, kernel_size=8, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=hp_units, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='sigmoid')
  ])
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
              metrics=['accuracy'])
    return model
  
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=20,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kttp')

es = EarlyStopping(monitor='val_loss', patience=3, verbose=1)
tuner.search(training_dataset, epochs=50, validation_data=val_data, validation_steps=20, callbacks = [es])

best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# INFO:tensorflow:Reloading Tuner from my_dir\intro_to_kttp\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 464 and the optimal learning rate for the optimizer
# is 0.001.

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(training_dataset, epochs=20, validation_data=val_data, validation_steps=20)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/20
# 194/194 [==============================] - 3s 7ms/step - loss: 0.4979 - accuracy: 0.7506 - val_loss: 0.3883 - val_accuracy: 0.8484
# Epoch 2/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.3185 - accuracy: 0.8686 - val_loss: 0.3647 - val_accuracy: 0.8531
# Epoch 3/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.2634 - accuracy: 0.8935 - val_loss: 0.3806 - val_accuracy: 0.8594
# Epoch 4/20
# 194/194 [==============================] - 1s 5ms/step - loss: 0.2349 - accuracy: 0.9036 - val_loss: 0.3871 - val_accuracy: 0.8578
# Epoch 5/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.2043 - accuracy: 0.9187 - val_loss: 0.4453 - val_accuracy: 0.8531
# Epoch 6/20
# 194/194 [==============================] - 1s 5ms/step - loss: 0.1850 - accuracy: 0.9250 - val_loss: 0.4417 - val_accuracy: 0.8484
# Epoch 7/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1680 - accuracy: 0.9324 - val_loss: 0.4735 - val_accuracy: 0.8531
# Epoch 8/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1430 - accuracy: 0.9437 - val_loss: 0.5310 - val_accuracy: 0.8500
# Epoch 9/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1347 - accuracy: 0.9450 - val_loss: 0.5669 - val_accuracy: 0.8516
# Epoch 10/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1223 - accuracy: 0.9527 - val_loss: 0.5990 - val_accuracy: 0.8469
# Epoch 11/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1185 - accuracy: 0.9527 - val_loss: 0.6517 - val_accuracy: 0.8406
# Epoch 12/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1109 - accuracy: 0.9553 - val_loss: 0.6779 - val_accuracy: 0.8422
# Epoch 13/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1071 - accuracy: 0.9564 - val_loss: 0.6939 - val_accuracy: 0.8516
# Epoch 14/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1024 - accuracy: 0.9603 - val_loss: 0.7260 - val_accuracy: 0.8391
# Epoch 15/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0937 - accuracy: 0.9614 - val_loss: 0.7691 - val_accuracy: 0.8531
# Epoch 16/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0944 - accuracy: 0.9630 - val_loss: 0.7823 - val_accuracy: 0.8609
# Epoch 17/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0899 - accuracy: 0.9634 - val_loss: 0.7899 - val_accuracy: 0.8422
# Epoch 18/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0837 - accuracy: 0.9658 - val_loss: 0.8476 - val_accuracy: 0.8438
# Epoch 19/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0790 - accuracy: 0.9677 - val_loss: 0.8747 - val_accuracy: 0.8562
# Epoch 20/20
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0828 - accuracy: 0.9685 - val_loss: 0.9287 - val_accuracy: 0.8484
# Best epoch: 16

# %%
def plot_graphs(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+metric], '')
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(['Training_'+metric, 'Val_'+metric])
    plt.savefig('cnn_loss_curve.png')

plt.figure(figsize=(16, 6))
plt.subplot(1, 2, 1)
plot_graphs(history, 'accuracy')
plt.subplot(1, 2, 2)
plot_graphs(history, 'loss')

# %%
hypermodel = tuner.hypermodel.build(best_hps)
hypermodel.fit(training_dataset, epochs=best_epoch , validation_data=val_data, validation_steps=20)
# Out:
# Epoch 1/16
# 194/194 [==============================] - 3s 7ms/step - loss: 0.5077 - accuracy: 0.7431 - val_loss: 0.3772 - val_accuracy: 0.8422
# Epoch 2/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.3184 - accuracy: 0.8635 - val_loss: 0.3498 - val_accuracy: 0.8516
# Epoch 3/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.2607 - accuracy: 0.8940 - val_loss: 0.3744 - val_accuracy: 0.8531
# Epoch 4/16
# 194/194 [==============================] - 1s 5ms/step - loss: 0.2275 - accuracy: 0.9064 - val_loss: 0.3980 - val_accuracy: 0.8547
# Epoch 5/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1963 - accuracy: 0.9193 - val_loss: 0.4462 - val_accuracy: 0.8484
# Epoch 6/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1709 - accuracy: 0.9303 - val_loss: 0.4777 - val_accuracy: 0.8484
# Epoch 7/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1569 - accuracy: 0.9379 - val_loss: 0.4993 - val_accuracy: 0.8578
# Epoch 8/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1448 - accuracy: 0.9400 - val_loss: 0.5287 - val_accuracy: 0.8500
# Epoch 9/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.1336 - accuracy: 0.9450 - val_loss: 0.5573 - val_accuracy: 0.8484
# Epoch 10/16
# 194/194 [==============================] - 1s 5ms/step - loss: 0.1184 - accuracy: 0.9519 - val_loss: 0.6121 - val_accuracy: 0.8516
# Epoch 11/16
# 194/194 [==============================] - 1s 7ms/step - loss: 0.1146 - accuracy: 0.9527 - val_loss: 0.6004 - val_accuracy: 0.8562
# Epoch 12/16
# 194/194 [==============================] - 1s 5ms/step - loss: 0.0998 - accuracy: 0.9584 - val_loss: 0.6791 - val_accuracy: 0.8578
# Epoch 13/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0999 - accuracy: 0.9605 - val_loss: 0.7072 - val_accuracy: 0.8531
# Epoch 14/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0938 - accuracy: 0.9598 - val_loss: 0.7563 - val_accuracy: 0.8469
# Epoch 15/16
# 194/194 [==============================] - 1s 6ms/step - loss: 0.0889 - accuracy: 0.9635 - val_loss: 0.8071 - val_accuracy: 0.8516
# Epoch 16/16
# 194/194 [==============================] - 1s 5ms/step - loss: 0.0886 - accuracy: 0.9637 - val_loss: 0.8750 - val_accuracy: 0.8547

# %%
pickle.dump(hypermodel, open("model_CNN.pkl", 'wb'))

# %%
eval_result = hypermodel.evaluate(training_dataset)
print("[train loss, train accuracy]:", eval_result)
# Out:
# 194/194 [==============================] - 1s 3ms/step - loss: 0.0602 - accuracy: 0.9740
# [train loss, train accuracy]: [0.06018796190619469, 0.974015474319458]

# %%
eval_result = hypermodel.evaluate(testing_data)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6564 - accuracy: 0.8654
# [test loss, test accuracy]: [0.6564247608184814, 0.8653594851493835]

# %%
predictions = (hypermodel.predict(X_test['tweet']) > 0.5).astype("int32")

# Classification Report
print("\n\033[1m"+"Performance on Test Set" + "\033[0m\n")
print(classification_report(y_test, predictions))

# Confusion Matrix
print("\n")
cm = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion matrix for Depressive (1)/ Non-Depressive (0) Tweets", size = 10);
plt.savefig('cnn_confusion_m.png')
plt.show()

# AUC-ROC Curve
print("\n")
pred_y_prob = hypermodel.predict(X_test['tweet']).ravel()   
fpr_rnn, tpr_rnn, thresh_rnn = roc_curve(y_test, pred_y_prob)
plt.plot(fpr_rnn, tpr_rnn, linestyle='--',color='orange', label="CNN")
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label="Logistic Regression")

plt.title("AUC-ROC curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig('AUC_ROC.png')
plt.show()
# Out:
# 24/24 [==============================] - 0s 3ms/step
#
# Performance on Test Set
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.85      0.88       459
#            1       0.80      0.88      0.84       306
#
#     accuracy                           0.87       765
#    macro avg       0.86      0.87      0.86       765
# weighted avg       0.87      0.87      0.87       765
# 24/24 [==============================] - 0s 3ms/step

# %%
df= pd.read_csv('OurMLdataset.csv')

# %%
df
# Out:
#                 id                                              tweet  label
# 0     1.228030e+18  cmon do not you want to see what kind of tatto...      0
# 1     5.158770e+17  what we need to do in life to be at peace when...      0
# 2     8.377520e+17  finish my research poster to present at a conf...      0
# 3     9.628340e+17                                   i be the problem      1
# 4     4.533340e+17  get to see my idol the other day wish she be s...      1
# ...            ...                                                ...    ...
# 7647  2.923020e+17  if you want to achieve anything in this world ...      0
# 7648  1.386030e+18  i have be wait to get verify before i send thi...      0
# 7649  9.460330e+17  i only lie so i do not have to see tear of dis...      1
# 7650  1.123660e+18  i tell my therapist i just want to be as happy...      0
# 7651  1.219850e+18  when i look at trump lawyer jay sekulow i see ...      0
#
# [7652 rows x 3 columns]

# %%
review_df = df[['tweet','label']]

# %%
review_df
# Out:
#                                                   tweet  label
# 0     cmon do not you want to see what kind of tatto...      0
# 1     what we need to do in life to be at peace when...      0
# 2     finish my research poster to present at a conf...      0
# 3                                      i be the problem      1
# 4     get to see my idol the other day wish she be s...      1
# ...                                                 ...    ...
# 7647  if you want to achieve anything in this world ...      0
# 7648  i have be wait to get verify before i send thi...      0
# 7649  i only lie so i do not have to see tear of dis...      1
# 7650  i tell my therapist i just want to be as happy...      0
# 7651  when i look at trump lawyer jay sekulow i see ...      0
#
# [7652 rows x 2 columns]

# %%
print(review_df.shape)
review_df.head(5)
# Out:
# (7652, 2)
#                                                tweet  label
# 0  cmon do not you want to see what kind of tatto...      0
# 1  what we need to do in life to be at peace when...      0
# 2  finish my research poster to present at a conf...      0
# 3                                   i be the problem      1
# 4  get to see my idol the other day wish she be s...      1

# %%
review_df["label"].value_counts()
# Out:
# 0    4593
# 1    3059
# Name: label, dtype: int64

# %%
sentiment_label = review_df.label.factorize()
sentiment_label
# Out:
# (array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  Int64Index([0, 1], dtype='int64'))

# %%
tweetno=review_df.tweet.values

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=5000)

tokenizer.fit_on_texts(tweetno)

# %%
encoded_docs = tokenizer.texts_to_sequences(tweetno)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

padded_sequence = pad_sequences(encoded_docs, maxlen=200)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense, Dropout, SpatialDropout1D
from tensorflow.keras.layers import Embedding

vocab_size = len(tokenizer.word_index) + 1

embedding_vector_length = 32
model = Sequential()
model.add(Embedding(vocab_size, embedding_vector_length, input_length=200))
model.add(SpatialDropout1D(0.25))
model.add(LSTM(50, dropout=0.5, recurrent_dropout=0.5))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, 200, 32)           269632
#
#  spatial_dropout1d_2 (Spatia  (None, 200, 32)          0
#  lDropout1D)
#
#  lstm_2 (LSTM)               (None, 50)                16600
#
#  dropout_12 (Dropout)        (None, 50)                0
#
#  dense_12 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 286,283
# Trainable params: 286,283
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(padded_sequence,sentiment_label[0],validation_split=0.2, epochs=5, batch_size=32)
# Out:
# Epoch 1/5
# 192/192 [==============================] - 47s 217ms/step - loss: 0.5225 - accuracy: 0.7375 - val_loss: 0.3780 - val_accuracy: 0.8517
# Epoch 2/5
# 192/192 [==============================] - 40s 207ms/step - loss: 0.3472 - accuracy: 0.8468 - val_loss: 0.2938 - val_accuracy: 0.8739
# Epoch 3/5
# 192/192 [==============================] - 40s 211ms/step - loss: 0.2510 - accuracy: 0.8945 - val_loss: 0.2750 - val_accuracy: 0.8785
# Epoch 4/5
# 192/192 [==============================] - 40s 208ms/step - loss: 0.2129 - accuracy: 0.9154 - val_loss: 0.2585 - val_accuracy: 0.8883
# Epoch 5/5
# 192/192 [==============================] - 40s 210ms/step - loss: 0.1817 - accuracy: 0.9299 - val_loss: 0.2682 - val_accuracy: 0.8857

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='acc')
plt.plot(history.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()

plt.savefig("Accuracy plot.jpg")

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')

plt.legend()
plt.show()

plt.savefig("Loss plt.jpg")

# %%
def predict_sentiment(text):
    tw = tokenizer.texts_to_sequences([text])
    tw = pad_sequences(tw,maxlen=200)
    prediction = int(model.predict(tw).round().item())
    print("Predicted label: ", sentiment_label[1][prediction])


test_sentence1 = df['tweet'][3]
predict_sentiment(test_sentence1)

test_sentence2 = df['tweet'][0]
predict_sentiment(test_sentence2)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Predicted label:  1
# 1/1 [==============================] - 0s 74ms/step
# Predicted label:  0

# %%
sentiment_label
# Out:
# (array([0, 0, 0, ..., 1, 0, 0], dtype=int64),
#  Int64Index([0, 1], dtype='int64'))

# %%
df['tweet'][3]
# Out:
# 'i be the problem'

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer

# Initialize the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Function to detect sentiment
def detect_sentiment(sentence):
    # Analyze the sentiment of the sentence using SentimentIntensityAnalyzer
    sentiment_scores = sia.polarity_scores(sentence)
    
    # Determine the overall sentiment label based on the compound score
    compound_score = sentiment_scores['compound']
    if compound_score >= 0.05:
        sentiment_label = 'Positive'
    elif compound_score <= -0.05:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    
    # Return the sentiment label and the sentiment scores
    return sentiment_label, sentiment_scores

# Example usage
sentence = input("Enter a sentence: ")
sentiment, scores = detect_sentiment(sentence)

print("Sentiment: ", sentiment)
print("Sentiment Scores: ", scores)
